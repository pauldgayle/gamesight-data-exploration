# %% [markdown]
# # Gamesight Genre Analysis
#
# This notebook analyzes the dataset from Gamesight.io, focusing on game genres and their positive review ratios.

# %% [markdown]
# ## 1. Import Libraries and Load Data
#
# We will import the necessary libraries and load the CSV data into a pandas DataFrame.

# %%
# %pip install pandas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("C:\\Users\\Paul Gayle\\Downloads\\gamesight.db.csv", index_col=0)
# Out:
# Requirement already satisfied: pandas in c:\users\paul gayle\anaconda3\lib\site-packages (2.2.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.26.0 in c:\users\paul gayle\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\paul gayle\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\paul gayle\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\paul gayle\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\paul gayle\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## 2. Explore DataFrame Structure
#
# Let's look at the first few rows to understand the structure of the dataset.

# %%
df.head()
# Out:
#                              release_date  \
# game
# Borderlands Game of the Year          NaN
# Earthworm Jim                         NaN
# GRID 2                                NaN
# Darksiders II                         NaN
# Realm of the Mad God Exalt            NaN
#
#                                                                          genres  \
# game
# Borderlands Game of the Year  Action,Action RPG,Adventure,Co-op,Comedy,Dark ...
# Earthworm Jim                 2D,Action,Adventure,Classic,Comedy,Masterpiece...
# GRID 2                        3D Vision,Action,Adventure,Arcade,Casual,Co-op...
# Darksiders II                 Action,Action RPG,Action-Adventure,Adventure,B...
# Realm of the Mad God Exalt    2D,Action,Adventure,Bullet Hell,Casual,Co-op,D...
#
#                               game_positive_review_count  \
# game
# Borderlands Game of the Year                       26657
# Earthworm Jim                                         39
# GRID 2                                             22851
# Darksiders II                                       5608
# Realm of the Mad God Exalt                         23429
#
#                               game_negative_review_count  game_price
# game
# Borderlands Game of the Year                        2847       29.99
# Earthworm Jim                                         45         NaN
# GRID 2                                              4511         NaN
# Darksiders II                                        612         NaN
# Realm of the Mad God Exalt                          4732         NaN

# %% [markdown]
# ## 3. Explode Genres Column
#
# The 'genres' column contains multiple genres separated by commas. We'll split this column and explode the DataFrame so each genre has its own row.

# %%
# Split genres and explode the DataFrame
df_exploded = df.copy()
df_exploded['genres'] = df_exploded['genres'].str.split(',')
df_exploded = df_exploded.explode('genres')
df_exploded['genres'] = df_exploded['genres'].str.strip()

df_exploded.head()
# Out:
#                              release_date      genres  \
# game
# Borderlands Game of the Year          NaN      Action
# Borderlands Game of the Year          NaN  Action RPG
# Borderlands Game of the Year          NaN   Adventure
# Borderlands Game of the Year          NaN       Co-op
# Borderlands Game of the Year          NaN      Comedy
#
#                               game_positive_review_count  \
# game
# Borderlands Game of the Year                       26657
# Borderlands Game of the Year                       26657
# Borderlands Game of the Year                       26657
# Borderlands Game of the Year                       26657
# Borderlands Game of the Year                       26657
#
#                               game_negative_review_count  game_price
# game
# Borderlands Game of the Year                        2847       29.99
# Borderlands Game of the Year                        2847       29.99
# Borderlands Game of the Year                        2847       29.99
# Borderlands Game of the Year                        2847       29.99
# Borderlands Game of the Year                        2847       29.99

# %% [markdown]
# ## 4. Calculate Positive Review Ratio
#
# We'll add a new column, `positive_review_ratio`, to both the original and exploded DataFrames. This column represents the ratio of positive reviews to total reviews for each game.

# %%
df['positive_review_ratio'] = df['game_positive_review_count'] / (df['game_positive_review_count'] + df['game_negative_review_count'])
df_exploded['positive_review_ratio'] = df_exploded['game_positive_review_count'] / (df_exploded['game_positive_review_count'] + df_exploded['game_negative_review_count'])

# %% [markdown]
# ## 5. Bin Positive Review Ratios
#
# To make analysis and visualization easier, we'll create bins for the positive review ratio and add a `review_ratio_bin` column to both DataFrames.

# %%
bins = [0, 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90, 1.00]
labels = ['0-10%', '11-20%', '21-30%', '31-40%', '41-50%', '51-60%', '61-70%', '71-80%', '81-90%', '91-100%']

df['review_ratio_bin'] = pd.cut(df['positive_review_ratio'], bins=bins, labels=labels, include_lowest=True)
df_exploded['review_ratio_bin'] = pd.cut(df_exploded['positive_review_ratio'], bins=bins, labels=labels, include_lowest=True)

# %% [markdown]
# ## 6. Genre-Level Analysis
#
# Let's analyze the average positive review ratio and the number of games for each genre.

# %%
# Calculate average positive review ratio by genre
avg_ratio_by_genre = df_exploded.groupby('genres')['positive_review_ratio'].mean()

# Count number of games per genre
count_by_genre = df_exploded['genres'].value_counts()

print("Average positive review ratio by genre:")
print(avg_ratio_by_genre)

print("\nNumber of games per genre:")
print(count_by_genre)
# Out:
# Average positive review ratio by genre:
# genres
# 1980s           0.866356
# 1990's          0.904419
# 2.5D            0.837200
# 2D              0.892348
# 2D Fighter      0.832934
#                   ...
# World War I     0.837910
# World War II    0.807103
# Wrestling       0.721488
# Zombies         0.837615
# e-sports        0.813150
# Name: positive_review_ratio, Length: 388, dtype: float64
#
# Number of games per genre:
# genres
# Action          865
# Singleplayer    793
# Adventure       670
# Multiplayer     562
# Atmospheric     441
#                ...
# Golf              1
# Pinball           1
# 6DOF              1
# Nonlinear         1
# Match 3           1
# Name: count, Length: 388, dtype: int64

# %% [markdown]
# ## 7. Filter Genres by Game Count
#
# We'll filter genres that appear in more than 100 and 300 games, then display the top genres by average positive review ratio.

# %%
# Genres with more than 100 games
valid_genres_100 = count_by_genre[count_by_genre > 100].index
filtered_avg_ratio_100 = avg_ratio_by_genre.loc[valid_genres_100]
top_10_filtered_100 = filtered_avg_ratio_100.sort_values(ascending=False).head(10)
print("Top 10 genres by average positive review ratio (game count > 100):")
print(top_10_filtered_100)

# Genres with more than 300 games
valid_genres_300 = count_by_genre[count_by_genre > 300].index
filtered_avg_ratio_300 = avg_ratio_by_genre.loc[valid_genres_300]
top_10_filtered_300 = filtered_avg_ratio_300.sort_values(ascending=False).head(10)
print("\nTop 10 genres by average positive review ratio (game count > 300):")
print(top_10_filtered_300)
# Out:
# Top 10 genres by average positive review ratio (game count > 100):
# genres
# Puzzle              0.900965
# Pixel Graphics      0.898123
# 2D                  0.892348
# Platformer          0.890917
# Great Soundtrack    0.887898
# Classic             0.886891
# Difficult           0.879603
# Comedy              0.879585
# Funny               0.878630
# Indie               0.876511
# Name: positive_review_ratio, dtype: float64
#
# Top 10 genres by average positive review ratio (game count > 300):
# genres
# Great Soundtrack    0.887898
# Indie               0.876511
# Story Rich          0.873501
# Atmospheric         0.866092
# Singleplayer        0.861638
# First-Person        0.854785
# Adventure           0.854190
# Action              0.853142
# RPG                 0.846601
# Open World          0.833527
# Name: positive_review_ratio, dtype: float64

# %% [markdown]
# ## 8. Visualize Top Genres by Positive Review Ratio
#
# Let's plot a bar chart of the top genres by average positive review ratio (for genres with more than 300 games).

# %%
top_10_filtered_300_percent = top_10_filtered_300 * 100

ax = top_10_filtered_300_percent.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title('Top 10 Genres by Avg Positive Review Ratio (%) (Game Count > 300)')
plt.ylabel('Average Positive Review Ratio (%)')
plt.xlabel('Genre')
plt.ylim(80, 90)  # Set y-axis limits for percentage
plt.xticks(rotation=45)
plt.tight_layout()

for i, v in enumerate(top_10_filtered_300_percent):
    ax.text(i, v + 0.3, f"{v:.2f}%", ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# ## 9. Genre Co-occurrence Analysis
#
# Let's analyze which genres frequently appear together in games. This will help us understand:
# 1. Common genre combinations
# 2. Which genres are most likely to be paired together
# 3. Visualize the relationships between different genres

# %%
import numpy as np
from itertools import combinations

# Create a pivot table for genre co-occurrences
def get_genre_combinations(x):
    genres = sorted(x)  # Sort to ensure consistent ordering
    return list(combinations(genres, 2))

# Get genre combinations for each game
genre_combinations = df['genres'].str.split(',').apply(lambda x: [g.strip() for g in x]).apply(get_genre_combinations)
genre_combinations = genre_combinations.explode()

# Count co-occurrences
co_occurrences = pd.DataFrame(genre_combinations.tolist(), columns=['genre1', 'genre2'])
co_occurrence_counts = pd.crosstab(co_occurrences['genre1'], co_occurrences['genre2'])

# Find the most common genres (appearing in more than 300 games)
genre_counts = df['genres'].str.split(',').explode().str.strip().value_counts()
top_genres = genre_counts[genre_counts > 300].index

# Filter co-occurrence matrix for top genres only
filtered_matrix = co_occurrence_counts.loc[top_genres, top_genres]

# Plot the heatmap for top genres
plt.figure(figsize=(12, 10))
sns.heatmap(filtered_matrix, 
            annot=True, 
            fmt='g', 
            cmap='YlOrRd',
            square=True)
plt.title('Genre Co-occurrence Matrix (Most Common Genres)')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# Find top genre combinations
print("\nTop 10 Most Common Genre Combinations:")
top_combinations = (
    co_occurrences.groupby(['genre1', 'genre2'])
    .size()
    .reset_index(name='count')
    .sort_values('count', ascending=False)
    .head(10)
)
print(top_combinations)
# Out:
# Top 10 Most Common Genre Combinations:
#             genre1        genre2  count
# 1856        Action  Singleplayer    699
# 1579        Action     Adventure    601
# 2916     Adventure  Singleplayer    571
# 1767        Action   Multiplayer    513
# 18406  Multiplayer  Singleplayer    422
# 1592        Action   Atmospheric    403
# 4293   Atmospheric  Singleplayer    399
# 1789        Action    Open World    365
# 2830     Adventure   Multiplayer    358
# 2672     Adventure   Atmospheric    354
